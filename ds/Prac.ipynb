# %%
impoort pandas as pd
data = pd.Dataframe(P{'group':['a','a','a','b','b','b','c','c','c'],'ounces': [4,3,12,6,7.5,8,3,5,6]})
# Out:
#   File "<ipython-input-1-b6cf4eeab7da>", line 1
#     impoort pandas as pd
#                  ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
data = pd.DataFrame({'group': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
                 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0

# %%
data.describe()
# Out:
#           ounces
# count   9.000000
# mean    6.055556
# std     2.855307
# min     3.000000
# 25%     4.000000
# 50%     6.000000
# 75%     7.500000
# max    12.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
# group     9 non-null object
# ounces    9 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 216.0+ bytes

# %%
import pandas as pd
data = pd.DataFrame({'Grp': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
                 'Ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6],
                    'status':[t,f,t,t,f,t,t,f]})
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-227b1a363471> in <module>()
#       2 data = pd.DataFrame({'Grp': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
#       3                  'Ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6],
# ----> 4                     'status':[t,f,t,t,f,t,t,f]})
#       5 data
#
# NameError: name 't' is not defined

# %%
import pandas as pd
data = pd.DataFrame({'Grp': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
                 'Ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6],
                    'status':[1,0,1,1,0,1,0,1,0]})
data
# Out:
#   Grp  Ounces  status
# 0   a     4.0       1
# 1   a     3.0       0
# 2   a    12.0       1
# 3   b     6.0       1
# 4   b     7.5       0
# 5   b     8.0       1
# 6   c     3.0       0
# 7   c     5.0       1
# 8   c     6.0       0

# %%
import pandas as pd
data = pd.DataFrame({'Grp': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
                 'Ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6],
                    'status':[1,0,1,1,0,1,0,1]})
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-cbe87a988d9d> in <module>()
#       2 data = pd.DataFrame({'Grp': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
#       3                  'Ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6],
# ----> 4                     'status':[1,0,1,1,0,1,0,1]})
#       5 data
#
# C:\Users\BBY\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     222                                  dtype=dtype, copy=copy)
#     223         elif isinstance(data, dict):
# --> 224             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     225         elif isinstance(data, ma.MaskedArray):
#     226             import numpy.ma.mrecords as mrecords
#
# C:\Users\BBY\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _init_dict(self, data, index, columns, dtype)
# ...

# %%
import pandas as pd
data = pd.DataFrame({'Grp': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
                 'Ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6],
                    'status':[1,0,1,1,0,1,0,1,0,1]})
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-9c3ba7ef49e2> in <module>()
#       2 data = pd.DataFrame({'Grp': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
#       3                  'Ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6],
# ----> 4                     'status':[1,0,1,1,0,1,0,1,0,1]})
#       5 data
#
# C:\Users\BBY\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     222                                  dtype=dtype, copy=copy)
#     223         elif isinstance(data, dict):
# --> 224             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     225         elif isinstance(data, ma.MaskedArray):
#     226             import numpy.ma.mrecords as mrecords
#
# C:\Users\BBY\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _init_dict(self, data, index, columns, dtype)
# ...

# %%
import pandas as pd
data = pd.DataFrame({'Grp': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
                 'Ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6],
                    'status':[1,0,1,1,0,1,0,1,0]})
data
# Out:
#   Grp  Ounces  status
# 0   a     4.0       1
# 1   a     3.0       0
# 2   a    12.0       1
# 3   b     6.0       1
# 4   b     7.5       0
# 5   b     8.0       1
# 6   c     3.0       0
# 7   c     5.0       1
# 8   c     6.0       0

# %%
data.describe()
# Out:
#           Ounces    status
# count   9.000000  9.000000
# mean    6.055556  0.555556
# std     2.855307  0.527046
# min     3.000000  0.000000
# 25%     4.000000  0.000000
# 50%     6.000000  1.000000
# 75%     7.500000  1.000000
# max    12.000000  1.000000

# %%
data.sort_values(by=['Grp','Ounces','status'], ascending=[False, True, True], inplace=True)
data
# Out:
#   Grp  Ounces  status
# 6   c     3.0       0
# 7   c     5.0       1
# 8   c     6.0       0
# 3   b     6.0       1
# 4   b     7.5       0
# 5   b     8.0       1
# 1   a     3.0       0
# 0   a     4.0       1
# 2   a    12.0       1

# %%
data.sort_values(by=['Grp','Ounces','status'], ascending=[False, True, True], inplace=False)
data
# Out:
#   Grp  Ounces  status
# 6   c     3.0       0
# 7   c     5.0       1
# 8   c     6.0       0
# 3   b     6.0       1
# 4   b     7.5       0
# 5   b     8.0       1
# 1   a     3.0       0
# 0   a     4.0       1
# 2   a    12.0       1

# %%
import pandas as pd
Data =pd.DataFrame({'grp':['a']*3 +['b']*2, 'ounces':[1,2,4,3,1,]})
data
# Out:
#   Grp  Ounces  status
# 6   c     3.0       0
# 7   c     5.0       1
# 8   c     6.0       0
# 3   b     6.0       1
# 4   b     7.5       0
# 5   b     8.0       1
# 1   a     3.0       0
# 0   a     4.0       1
# 2   a    12.0       1

# %%
import pandas as pd
Data =pd.DataFrame({'grp':['a']*3 +['b']*2, 'ounces':[1,2,4,3,1,]})

# %%
import pandas as pd
Data =pd.DataFrame({'grp':['a']*3 +['b']*2, 'ounces':[1,2,4,3,1,]})
Data
# Out:
#   grp  ounces
# 0   a       1
# 1   a       2
# 2   a       4
# 3   b       3
# 4   b       1

# %%
describe.Data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-65748f610b8b> in <module>()
# ----> 1 describe.Data()
#
# NameError: name 'describe' is not defined

# %%
Data.describe()
# Out:
#         ounces
# count  5.00000
# mean   2.20000
# std    1.30384
# min    1.00000
# 25%    1.00000
# 50%    2.00000
# 75%    3.00000
# max    4.00000

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
# grp       5 non-null object
# ounces    5 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 152.0+ bytes

# %%
Data.drop_duplicates()
# Out:
#   grp  ounces
# 0   a       1
# 1   a       2
# 2   a       4
# 3   b       3
# 4   b       1

# %%
Data.drop_duplicates(subset='grp')
# Out:
#   grp  ounces
# 0   a       1
# 3   b       3

# %%
import pandas as pd
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon', 'Pastrami','corned beef', 'Bacon', 'pastrami', 'honey ham','nova lox'],
                 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {
'bacon': 'pig',
'pulled pork': 'pig',
'pastrami': 'cow',
'corned beef': 'cow',
'honey ham': 'pig',
'nova lox': 'salmon'
}

def meat2animal(series):
    if series["food"]=='bacon':
        return 'pig'
    elif series["food"]=='pulled pork':
        return 'pig'
    elif series["food"]=='pastrami':
        return 'cow'
    elif series["food"]=='corned beef':
        return 'cow'
    elif series["food"]=='honey ham':
        return 'pig'
    else:
        return 'salmon'

# %%
data['animal'] = data['food'].map(str).map(meat_to_animal)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     NaN
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     NaN
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
data['animal'] = data['food'].map(str.lower).map(meat_to_animal)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
data['animal'] = data['food'].map(str.lower).map(meat_to_animal)
data
#comment: it is used for mapping food column with animal
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
data['animal'] = data['food'].map(str.lower)
data
# Out:
#           food  ounces       animal
# 0        bacon     4.0        bacon
# 1  pulled pork     3.0  pulled pork
# 2        bacon    12.0        bacon
# 3     Pastrami     6.0     pastrami
# 4  corned beef     7.5  corned beef
# 5        Bacon     8.0        bacon
# 6     pastrami     3.0     pastrami
# 7    honey ham     5.0    honey ham
# 8     nova lox     6.0     nova lox

# %%
data['animal'] = data['food'].map(str.lower).map(meat_to_animal)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
data = pd.read_csv('C:\Users\BBY\Downloads\ml-1m\ml-1m')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-33-820abee4a0e0> in <module>()
#       1
# ----> 2 data = pd.read_csv('C:\Users\BBY\Downloads\ml-1m\ml-1m')
#       3
#       4
#
# ...

# %%
df = pd.read_csv('C:\Users\BBY\Downloads\ml-1m\ml-1m')
df
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-34-7c244e4e1f20> in <module>()
# ----> 1 df = pd.read_csv('C:\Users\BBY\Downloads\ml-1m\ml-1m')
#       2 df
#
# ...

# %%
location=r'C:\Users\BBY\Downloads\ml-1m\ml-1m'

# %%
data = pd.read_csv(location,header=None)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-36-a11effbeaac0> in <module>()
# ----> 1 data = pd.read_csv(location,header=None)
#
# C:\Users\BBY\Anaconda2\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
import pandas as pd

# %%
location ='C:\Users\BBY\Desktop\data_science\ml-1m'

# %%
data = pd.read_csv(location,header=None)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-39-a11effbeaac0> in <module>()
# ----> 1 data = pd.read_csv(location,header=None)
#
# C:\Users\BBY\Anaconda2\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
location =r'C:\Users\BBY\Desktop\data_science\ml-1m'

# %%
d1 = pd.read_csv(location,header=None)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-42-a11effbeaac0> in <module>()
# ----> 1 data = pd.read_csv(location,header=None)
#
# C:\Users\BBY\Anaconda2\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
d1 = pd.read_csv(location,header=None)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-43-04e5890361f4> in <module>()
# ----> 1 d1 = pd.read_csv(location,header=None)
#
# C:\Users\BBY\Anaconda2\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
location =r'C:\Users\BBY\Desktop\data_science\ml-1m'

# %%
d1 = pd.read_csv(location,header=None)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-46-04e5890361f4> in <module>()
# ----> 1 d1 = pd.read_csv(location,header=None)
#
# C:\Users\BBY\Anaconda2\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
data = pd.read_csv(location,header=None)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-47-a11effbeaac0> in <module>()
# ----> 1 data = pd.read_csv(location,header=None)
#
# C:\Users\BBY\Anaconda2\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
location=r'C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv'

# %%
data = pd.read_csv(location,header=None)

# %%
data.describe()
# Out:
#                                0
# count                    1000209
# unique                   1000209
# top     2063::3269::3::974664026
# freq                           1

# %%
data
# Out:
#                                 0
# 0           1::1193::5::978300760
# 1            1::661::3::978302109
# 2            1::914::3::978301968
# 3           1::3408::4::978300275
# 4           1::2355::5::978824291
# 5           1::1197::3::978302268
# 6           1::1287::5::978302039
# 7           1::2804::5::978300719
# 8            1::594::4::978302268
# 9            1::919::4::978301368
# 10           1::595::5::978824268
# 11           1::938::4::978301752
# 12          1::2398::4::978302281
# 13          1::2918::4::978302124
# 14          1::1035::5::978301753
# 15          1::2791::4::978302188
# 16          1::2687::3::978824268
# 17          1::2018::4::978301777
# 18          1::3105::5::978301713
# 19          1::2797::4::978302039
# 20          1::2321::3::978302205
# 21           1::720::3::978300760
# 22          1::1270::5::978300055
# 23           1::527::5::978824195
# 24          1::2340::3::978300103
# 25            1::48::5::978824351
# ...

# %%
loc='C:\Users\BBY\Desktop\data_science\ml-1m\movies'

# %%
data=pd.read_csv(location,header=None)

# %%
data=pd.read_csv(loc)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-59-e20880feff64> in <module>()
# ----> 1 data=pd.read_csv(loc)
#
# C:\Users\BBY\Anaconda2\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
data=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\movies.csv',header=None)
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-60-8da21a50d756> in <module>()
# ----> 1 data=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\movies.csv',header=None)
#
# ...

# %%
data=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\movies.csv',sep="::")
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
data
# Out:
#          1                                   Toy Story (1995)  \
# 0        2                                     Jumanji (1995)
# 1        3                            Grumpier Old Men (1995)
# 2        4                           Waiting to Exhale (1995)
# 3        5                 Father of the Bride Part II (1995)
# 4        6                                        Heat (1995)
# 5        7                                     Sabrina (1995)
# 6        8                                Tom and Huck (1995)
# 7        9                                Sudden Death (1995)
# 8       10                                   GoldenEye (1995)
# 9       11                     American President, The (1995)
# 10      12                 Dracula: Dead and Loving It (1995)
# 11      13                                       Balto (1995)
# 12      14                                       Nixon (1995)
# 13      15                            Cutthroat Island (1995)
# ...

# %%
data=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\users.csv',sep="::")
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
data
# Out:
#          1  F  1.1  10  48067
# 0        2  M   56  16  70072
# 1        3  M   25  15  55117
# 2        4  M   45   7  02460
# 3        5  M   25  20  55455
# 4        6  F   50   9  55117
# 5        7  M   35   1  06810
# 6        8  M   25  12  11413
# 7        9  M   25  17  61614
# 8       10  F   35   1  95370
# 9       11  F   25   1  04093
# 10      12  M   25  12  32793
# 11      13  M   45   1  93304
# 12      14  M   35   0  60126
# 13      15  M   25   7  22903
# 14      16  F   35   0  20670
# 15      17  M   50   1  95350
# 16      18  F   18   3  95825
# 17      19  M    1  10  48073
# 18      20  M   25  14  55113
# 19      21  M   18  16  99353
# 20      22  M   18  15  53706
# 21      23  M   35   0  90049
# 22      24  F   25   7  10023
# 23      25  M   18   4  01609
# 24      26  M   25   7  23112
# 25      27  M   25  11  19130
# 26      28  F   25   1  14607
# 27      29  M   35   7  33407
# 28      30  F   35   7  19143
# 29      31  M   56   7  06840
# ...

# %%
data1=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\users.csv',sep="::")
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
data1
# Out:
#          1  F  1.1  10  48067
# 0        2  M   56  16  70072
# 1        3  M   25  15  55117
# 2        4  M   45   7  02460
# 3        5  M   25  20  55455
# 4        6  F   50   9  55117
# 5        7  M   35   1  06810
# 6        8  M   25  12  11413
# 7        9  M   25  17  61614
# 8       10  F   35   1  95370
# 9       11  F   25   1  04093
# 10      12  M   25  12  32793
# 11      13  M   45   1  93304
# 12      14  M   35   0  60126
# 13      15  M   25   7  22903
# 14      16  F   35   0  20670
# 15      17  M   50   1  95350
# 16      18  F   18   3  95825
# 17      19  M    1  10  48073
# 18      20  M   25  14  55113
# 19      21  M   18  16  99353
# 20      22  M   18  15  53706
# 21      23  M   35   0  90049
# 22      24  F   25   7  10023
# 23      25  M   18   4  01609
# 24      26  M   25   7  23112
# 25      27  M   25  11  19130
# 26      28  F   25   1  14607
# 27      29  M   35   7  33407
# 28      30  F   35   7  19143
# 29      31  M   56   7  06840
# ...

# %%
data
# Out:
#          1  F  1.1  10  48067
# 0        2  M   56  16  70072
# 1        3  M   25  15  55117
# 2        4  M   45   7  02460
# 3        5  M   25  20  55455
# 4        6  F   50   9  55117
# 5        7  M   35   1  06810
# 6        8  M   25  12  11413
# 7        9  M   25  17  61614
# 8       10  F   35   1  95370
# 9       11  F   25   1  04093
# 10      12  M   25  12  32793
# 11      13  M   45   1  93304
# 12      14  M   35   0  60126
# 13      15  M   25   7  22903
# 14      16  F   35   0  20670
# 15      17  M   50   1  95350
# 16      18  F   18   3  95825
# 17      19  M    1  10  48073
# 18      20  M   25  14  55113
# 19      21  M   18  16  99353
# 20      22  M   18  15  53706
# 21      23  M   35   0  90049
# 22      24  F   25   7  10023
# 23      25  M   18   4  01609
# 24      26  M   25   7  23112
# 25      27  M   25  11  19130
# 26      28  F   25   1  14607
# 27      29  M   35   7  33407
# 28      30  F   35   7  19143
# 29      31  M   56   7  06840
# ...

# %%
mov=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\movies.csv',header=None)
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-69-cf08b084d0fb> in <module>()
# ----> 1 mov=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\movies.csv',header=None)
#
# ...

# %%
data=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\movies.csv',header=None)
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-70-8da21a50d756> in <module>()
# ----> 1 data=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\movies.csv',header=None)
#
# ...

# %%
data=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\movies.csv',sep="::")
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
data
# Out:
#          1                                   Toy Story (1995)  \
# 0        2                                     Jumanji (1995)
# 1        3                            Grumpier Old Men (1995)
# 2        4                           Waiting to Exhale (1995)
# 3        5                 Father of the Bride Part II (1995)
# 4        6                                        Heat (1995)
# 5        7                                     Sabrina (1995)
# 6        8                                Tom and Huck (1995)
# 7        9                                Sudden Death (1995)
# 8       10                                   GoldenEye (1995)
# 9       11                     American President, The (1995)
# 10      12                 Dracula: Dead and Loving It (1995)
# 11      13                                       Balto (1995)
# 12      14                                       Nixon (1995)
# 13      15                            Cutthroat Island (1995)
# ...

# %%
data1
# Out:
#          1  F  1.1  10  48067
# 0        2  M   56  16  70072
# 1        3  M   25  15  55117
# 2        4  M   45   7  02460
# 3        5  M   25  20  55455
# 4        6  F   50   9  55117
# 5        7  M   35   1  06810
# 6        8  M   25  12  11413
# 7        9  M   25  17  61614
# 8       10  F   35   1  95370
# 9       11  F   25   1  04093
# 10      12  M   25  12  32793
# 11      13  M   45   1  93304
# 12      14  M   35   0  60126
# 13      15  M   25   7  22903
# 14      16  F   35   0  20670
# 15      17  M   50   1  95350
# 16      18  F   18   3  95825
# 17      19  M    1  10  48073
# 18      20  M   25  14  55113
# 19      21  M   18  16  99353
# 20      22  M   18  15  53706
# 21      23  M   35   0  90049
# 22      24  F   25   7  10023
# 23      25  M   18   4  01609
# 24      26  M   25   7  23112
# 25      27  M   25  11  19130
# 26      28  F   25   1  14607
# 27      29  M   35   7  33407
# 28      30  F   35   7  19143
# 29      31  M   56   7  06840
# ...

# %%
data2=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv',sep="::")
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-74-aa19f39ca0ab> in <module>()
# ----> 1 data2=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv',sep="::")
#
# ...

# %%
data2=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv',sep="::",header=None)
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-75-d8b90fba9134> in <module>()
# ----> 1 data2=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv',sep="::",header=None)
#
# ...

# %%
data2=pd.read_csv(r'C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv',sep="::",header=None)
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
data2
# Out:
#             0     1  2          3
# 0           1  1193  5  978300760
# 1           1   661  3  978302109
# 2           1   914  3  978301968
# 3           1  3408  4  978300275
# 4           1  2355  5  978824291
# 5           1  1197  3  978302268
# 6           1  1287  5  978302039
# 7           1  2804  5  978300719
# 8           1   594  4  978302268
# 9           1   919  4  978301368
# 10          1   595  5  978824268
# 11          1   938  4  978301752
# 12          1  2398  4  978302281
# 13          1  2918  4  978302124
# 14          1  1035  5  978301753
# 15          1  2791  4  978302188
# 16          1  2687  3  978824268
# 17          1  2018  4  978301777
# 18          1  3105  5  978301713
# 19          1  2797  4  978302039
# 20          1  2321  3  978302205
# 21          1   720  3  978300760
# 22          1  1270  5  978300055
# 23          1   527  5  978824195
# 24          1  2340  3  978300103
# 25          1    48  5  978824351
# ...

# %%
data2=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\users.csv',sep="::",header=None)
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
data2
# Out:
#          0  1   2   3      4
# 0        1  F   1  10  48067
# 1        2  M  56  16  70072
# 2        3  M  25  15  55117
# 3        4  M  45   7  02460
# 4        5  M  25  20  55455
# 5        6  F  50   9  55117
# 6        7  M  35   1  06810
# 7        8  M  25  12  11413
# 8        9  M  25  17  61614
# 9       10  F  35   1  95370
# 10      11  F  25   1  04093
# 11      12  M  25  12  32793
# 12      13  M  45   1  93304
# 13      14  M  35   0  60126
# 14      15  M  25   7  22903
# 15      16  F  35   0  20670
# 16      17  M  50   1  95350
# 17      18  F  18   3  95825
# 18      19  M   1  10  48073
# 19      20  M  25  14  55113
# 20      21  M  18  16  99353
# 21      22  M  18  15  53706
# 22      23  M  35   0  90049
# 23      24  F  25   7  10023
# 24      25  M  18   4  01609
# 25      26  M  25   7  23112
# 26      27  M  25  11  19130
# 27      28  F  25   1  14607
# 28      29  M  35   7  33407
# 29      30  F  35   7  19143
# ...    ... ..  ..  ..    ...
# ...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6137cde4893c> in <module>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ab3c103dfee6> in <module>()
# ----> 1 data1
#
# NameError: name 'data1' is not defined

# %%
datau=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\users.csv',sep="::",header=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3aabc53d7a2d> in <module>()
# ----> 1 datau=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\users.csv',sep="::",header=None)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
datau=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\users.csv',sep="::",header=None)
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
datau
# Out:
#          0  1   2   3      4
# 0        1  F   1  10  48067
# 1        2  M  56  16  70072
# 2        3  M  25  15  55117
# 3        4  M  45   7  02460
# 4        5  M  25  20  55455
# 5        6  F  50   9  55117
# 6        7  M  35   1  06810
# 7        8  M  25  12  11413
# 8        9  M  25  17  61614
# 9       10  F  35   1  95370
# 10      11  F  25   1  04093
# 11      12  M  25  12  32793
# 12      13  M  45   1  93304
# 13      14  M  35   0  60126
# 14      15  M  25   7  22903
# 15      16  F  35   0  20670
# 16      17  M  50   1  95350
# 17      18  F  18   3  95825
# 18      19  M   1  10  48073
# 19      20  M  25  14  55113
# 20      21  M  18  16  99353
# 21      22  M  18  15  53706
# 22      23  M  35   0  90049
# 23      24  F  25   7  10023
# 24      25  M  18   4  01609
# 25      26  M  25   7  23112
# 26      27  M  25  11  19130
# 27      28  F  25   1  14607
# 28      29  M  35   7  33407
# 29      30  F  35   7  19143
# ...    ... ..  ..  ..    ...
# ...

# %%
datam=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\movies.csv',sep="::",header=None)
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
datar=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\rates.csv',sep="::",header=None)
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-7-23e7543ca2f0> in <module>()
# ----> 1 datar=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\rates.csv',sep="::",header=None)
#
# ...

# %%
datar=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv',sep="::",header=None)
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-9-b98fffa7a0db> in <module>()
# ----> 1 datar=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv',sep="::",header=None)
#
# ...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6137cde4893c> in <module>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
datau
# Out:
#          0  1   2   3      4
# 0        1  F   1  10  48067
# 1        2  M  56  16  70072
# 2        3  M  25  15  55117
# 3        4  M  45   7  02460
# 4        5  M  25  20  55455
# 5        6  F  50   9  55117
# 6        7  M  35   1  06810
# 7        8  M  25  12  11413
# 8        9  M  25  17  61614
# 9       10  F  35   1  95370
# 10      11  F  25   1  04093
# 11      12  M  25  12  32793
# 12      13  M  45   1  93304
# 13      14  M  35   0  60126
# 14      15  M  25   7  22903
# 15      16  F  35   0  20670
# 16      17  M  50   1  95350
# 17      18  F  18   3  95825
# 18      19  M   1  10  48073
# 19      20  M  25  14  55113
# 20      21  M  18  16  99353
# 21      22  M  18  15  53706
# 22      23  M  35   0  90049
# 23      24  F  25   7  10023
# 24      25  M  18   4  01609
# 25      26  M  25   7  23112
# 26      27  M  25  11  19130
# 27      28  F  25   1  14607
# 28      29  M  35   7  33407
# 29      30  F  35   7  19143
# ...    ... ..  ..  ..    ...
# ...

# %%
datam
# Out:
#          0                                                  1  \
# 0        1                                   Toy Story (1995)
# 1        2                                     Jumanji (1995)
# 2        3                            Grumpier Old Men (1995)
# 3        4                           Waiting to Exhale (1995)
# 4        5                 Father of the Bride Part II (1995)
# 5        6                                        Heat (1995)
# 6        7                                     Sabrina (1995)
# 7        8                                Tom and Huck (1995)
# 8        9                                Sudden Death (1995)
# 9       10                                   GoldenEye (1995)
# 10      11                     American President, The (1995)
# 11      12                 Dracula: Dead and Loving It (1995)
# 12      13                                       Balto (1995)
# 13      14                                       Nixon (1995)
# ...

# %%
datar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-48d8f2296f38> in <module>()
# ----> 1 datar
#
# NameError: name 'datar' is not defined

# %%
data=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv',sep"::",header=None)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-17-f097e95cbb00> in <module>()
# ----> 1 data=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv',header=None)
#
# ...

# %%
pd.read_table(C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv)
# Out:
#   File "<ipython-input-18-d5510df91790>", line 1
#     pd.read_table(C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv)
#                    ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
pd.read_table(C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv)
# Out:
#   File "<ipython-input-21-51dc43a7b68d>", line 2
#     pd.read_table(C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv)
#                    ^
# SyntaxError: invalid syntax

# %%
pd.read_table(\ml-1m\ratings.csv)
# Out:
#   File "<ipython-input-23-968ee1d16d19>", line 1
#     pd.read_table(\ml-1m\ratings.csv)
#                                      ^
# SyntaxError: unexpected character after line continuation character

# %%
data=pd.read_table(\ml-1m\ratings.csv)
# Out:
#   File "<ipython-input-25-9f9774aedeb7>", line 1
#     data=pd.read_table(\ml-1m\ratings.csv)
#                                           ^
# SyntaxError: unexpected character after line continuation character

# %%
datam
# Out:
#          0                                                  1  \
# 0        1                                   Toy Story (1995)
# 1        2                                     Jumanji (1995)
# 2        3                            Grumpier Old Men (1995)
# 3        4                           Waiting to Exhale (1995)
# 4        5                 Father of the Bride Part II (1995)
# 5        6                                        Heat (1995)
# 6        7                                     Sabrina (1995)
# 7        8                                Tom and Huck (1995)
# 8        9                                Sudden Death (1995)
# 9       10                                   GoldenEye (1995)
# 10      11                     American President, The (1995)
# 11      12                 Dracula: Dead and Loving It (1995)
# 12      13                                       Balto (1995)
# 13      14                                       Nixon (1995)
# ...

# %%
datau
# Out:
#          0  1   2   3      4
# 0        1  F   1  10  48067
# 1        2  M  56  16  70072
# 2        3  M  25  15  55117
# 3        4  M  45   7  02460
# 4        5  M  25  20  55455
# 5        6  F  50   9  55117
# 6        7  M  35   1  06810
# 7        8  M  25  12  11413
# 8        9  M  25  17  61614
# 9       10  F  35   1  95370
# 10      11  F  25   1  04093
# 11      12  M  25  12  32793
# 12      13  M  45   1  93304
# 13      14  M  35   0  60126
# 14      15  M  25   7  22903
# 15      16  F  35   0  20670
# 16      17  M  50   1  95350
# 17      18  F  18   3  95825
# 18      19  M   1  10  48073
# 19      20  M  25  14  55113
# 20      21  M  18  16  99353
# 21      22  M  18  15  53706
# 22      23  M  35   0  90049
# 23      24  F  25   7  10023
# 24      25  M  18   4  01609
# 25      26  M  25   7  23112
# 26      27  M  25  11  19130
# 27      28  F  25   1  14607
# 28      29  M  35   7  33407
# 29      30  F  35   7  19143
# ...    ... ..  ..  ..    ...
# ...

# %%
datar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-48d8f2296f38> in <module>()
# ----> 1 datar
#
# NameError: name 'datar' is not defined

# %%
datar=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv',sep="::")
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-29-e6838d96fb21> in <module>()
# ----> 1 datar=pd.read_csv('C:\Users\BBY\Desktop\data_science\ml-1m\ratings.csv',sep="::")
#
# ...

# %%
datar=pd.read_table('ratings.dat',sep='::',names=['user-id','movies-id','rating','timestamp'])
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
datar
# Out:
#          user-id  movies-id  rating  timestamp
# 0              1       1193       5  978300760
# 1              1        661       3  978302109
# 2              1        914       3  978301968
# 3              1       3408       4  978300275
# 4              1       2355       5  978824291
# 5              1       1197       3  978302268
# 6              1       1287       5  978302039
# 7              1       2804       5  978300719
# 8              1        594       4  978302268
# 9              1        919       4  978301368
# 10             1        595       5  978824268
# 11             1        938       4  978301752
# 12             1       2398       4  978302281
# 13             1       2918       4  978302124
# 14             1       1035       5  978301753
# 15             1       2791       4  978302188
# 16             1       2687       3  978824268
# 17             1       2018       4  978301777
# 18             1       3105       5  978301713
# ...

# %%
datau=pd.read_table('users.dat',sep='::')
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
datau
# Out:
#          1  F  1.1  10  48067
# 0        2  M   56  16  70072
# 1        3  M   25  15  55117
# 2        4  M   45   7  02460
# 3        5  M   25  20  55455
# 4        6  F   50   9  55117
# 5        7  M   35   1  06810
# 6        8  M   25  12  11413
# 7        9  M   25  17  61614
# 8       10  F   35   1  95370
# 9       11  F   25   1  04093
# 10      12  M   25  12  32793
# 11      13  M   45   1  93304
# 12      14  M   35   0  60126
# 13      15  M   25   7  22903
# 14      16  F   35   0  20670
# 15      17  M   50   1  95350
# 16      18  F   18   3  95825
# 17      19  M    1  10  48073
# 18      20  M   25  14  55113
# 19      21  M   18  16  99353
# 20      22  M   18  15  53706
# 21      23  M   35   0  90049
# 22      24  F   25   7  10023
# 23      25  M   18   4  01609
# 24      26  M   25   7  23112
# 25      27  M   25  11  19130
# 26      28  F   25   1  14607
# 27      29  M   35   7  33407
# 28      30  F   35   7  19143
# 29      31  M   56   7  06840
# ...

# %%
import pandas as pd
datam=pd.read_table('movies.dat',sep='::',names=['movies-id','title','gernes'])
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
datam
# Out:
#       movies-id                                              title  \
# 0             1                                   Toy Story (1995)
# 1             2                                     Jumanji (1995)
# 2             3                            Grumpier Old Men (1995)
# 3             4                           Waiting to Exhale (1995)
# 4             5                 Father of the Bride Part II (1995)
# 5             6                                        Heat (1995)
# 6             7                                     Sabrina (1995)
# 7             8                                Tom and Huck (1995)
# 8             9                                Sudden Death (1995)
# 9            10                                   GoldenEye (1995)
# 10           11                     American President, The (1995)
# 11           12                 Dracula: Dead and Loving It (1995)
# 12           13                                       Balto (1995)
# ...

# %%
datac=pd.concat([datam,datar])

# %%
datac

# %%
datac

# %%
datac=pd.concat([datam,datar])

# %%
datac
# Out:
#                                gernes  movies-id  rating    timestamp  \
# 0         Animation|Children's|Comedy          1     NaN          NaN
# 1        Adventure|Children's|Fantasy          2     NaN          NaN
# 2                      Comedy|Romance          3     NaN          NaN
# 3                        Comedy|Drama          4     NaN          NaN
# 4                              Comedy          5     NaN          NaN
# 5               Action|Crime|Thriller          6     NaN          NaN
# 6                      Comedy|Romance          7     NaN          NaN
# 7                Adventure|Children's          8     NaN          NaN
# 8                              Action          9     NaN          NaN
# 9           Action|Adventure|Thriller         10     NaN          NaN
# 10               Comedy|Drama|Romance         11     NaN          NaN
# 11                      Comedy|Horror         12     NaN          NaN
# ...

# %%
srt1=pd.sort_values(by='rating',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-7d0cb564ee51> in <module>()
# ----> 1 srt1=pd.sort_values(by='rating',ascending=False)
#
# AttributeError: 'module' object has no attribute 'sort_values'

# %%
srt1=pd.sort_values(by='rating', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-734d61e3e1fd> in <module>()
# ----> 1 srt1=pd.sort_values(by='rating', ascending=False)
#
# AttributeError: 'module' object has no attribute 'sort_values'

# %%
import pandas as pd

# %%
srt1=datac.sort_values(by='rating', ascending=False)

# %%
srt1[:10]
# Out:
#        gernes  movies-id  rating    timestamp title  user-id
# 0         NaN       1193     5.0  978300760.0   NaN      1.0
# 241580    NaN       1233     5.0  974766946.0   NaN   1451.0
# 241592    NaN       1242     5.0  974759202.0   NaN   1451.0
# 679613    NaN       3421     5.0  965452027.0   NaN   4072.0
# 241588    NaN       1097     5.0  974762970.0   NaN   1451.0
# 241587    NaN        708     5.0  974763838.0   NaN   1451.0
# 241584    NaN       1094     5.0  974763334.0   NaN   1451.0
# 241581    NaN       1090     5.0  974768584.0   NaN   1451.0
# 241579    NaN       1231     5.0  975826665.0   NaN   1451.0
# 241595    NaN       2985     5.0  974763096.0   NaN   1451.0

# %% [raw]
# datam

# %%
datamm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-d7d4438a607f> in <module>()
# ----> 1 datamm
#
# NameError: name 'datamm' is not defined

# %%
datam
# Out:
#       movies-id                                              title  \
# 0             1                                   Toy Story (1995)
# 1             2                                     Jumanji (1995)
# 2             3                            Grumpier Old Men (1995)
# 3             4                           Waiting to Exhale (1995)
# 4             5                 Father of the Bride Part II (1995)
# 5             6                                        Heat (1995)
# 6             7                                     Sabrina (1995)
# 7             8                                Tom and Huck (1995)
# 8             9                                Sudden Death (1995)
# 9            10                                   GoldenEye (1995)
# 10           11                     American President, The (1995)
# 11           12                 Dracula: Dead and Loving It (1995)
# 12           13                                       Balto (1995)
# ...

# %%
pd.read_table
# Out:
#          user-id  movie-id  rating  timestamp
# 0              1      1193       5  978300760
# 1              1       661       3  978302109
# 2              1       914       3  978301968
# 3              1      3408       4  978300275
# 4              1      2355       5  978824291
# 5              1      1197       3  978302268
# 6              1      1287       5  978302039
# 7              1      2804       5  978300719
# 8              1       594       4  978302268
# 9              1       919       4  978301368
# 10             1       595       5  978824268
# 11             1       938       4  978301752
# 12             1      2398       4  978302281
# 13             1      2918       4  978302124
# 14             1      1035       5  978301753
# 15             1      2791       4  978302188
# 16             1      2687       3  978824268
# 17             1      2018       4  978301777
# 18             1      3105       5  978301713
# ...

# %%
srt1=pd.merge(datar,datam, on='movies-id')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-11602304b9f7> in <module>()
# ----> 1 srt1=pd.merge(datar,datam, on='movies-id')
#
# NameError: name 'pd' is not defined

# %%
datam
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c4b03a766e2d> in <module>()
# ----> 1 datam
#
# NameError: name 'datam' is not defined

# %%
datam.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-34916d86dc6f> in <module>()
# ----> 1 datam.describe()
#
# NameError: name 'datam' is not defined

# %%
datam
# Out:
#       movies-id                                              title  \
# 0             1                                   Toy Story (1995)
# 1             2                                     Jumanji (1995)
# 2             3                            Grumpier Old Men (1995)
# 3             4                           Waiting to Exhale (1995)
# 4             5                 Father of the Bride Part II (1995)
# 5             6                                        Heat (1995)
# 6             7                                     Sabrina (1995)
# 7             8                                Tom and Huck (1995)
# 8             9                                Sudden Death (1995)
# 9            10                                   GoldenEye (1995)
# 10           11                     American President, The (1995)
# 11           12                 Dracula: Dead and Loving It (1995)
# 12           13                                       Balto (1995)
# ...

# %%
datau
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-cccdd85e5956> in <module>()
# ----> 1 datau
#
# NameError: name 'datau' is not defined

# %%
datar=pd.read_table('ratings.dat',sep='::',names=['user-id','movies-id','rating','timestamp'])
# Out:
# C:\Users\BBY\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
datar
# Out:
#          user-id  movies-id  rating  timestamp
# 0              1       1193       5  978300760
# 1              1        661       3  978302109
# 2              1        914       3  978301968
# 3              1       3408       4  978300275
# 4              1       2355       5  978824291
# 5              1       1197       3  978302268
# 6              1       1287       5  978302039
# 7              1       2804       5  978300719
# 8              1        594       4  978302268
# 9              1        919       4  978301368
# 10             1        595       5  978824268
# 11             1        938       4  978301752
# 12             1       2398       4  978302281
# 13             1       2918       4  978302124
# 14             1       1035       5  978301753
# 15             1       2791       4  978302188
# 16             1       2687       3  978824268
# 17             1       2018       4  978301777
# 18             1       3105       5  978301713
# ...
